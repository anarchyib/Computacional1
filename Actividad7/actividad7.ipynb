# %%
def vectorfield(w, t, p):

    x1, y1, x2, y2 = w
    m1, m2, k1, k2, b1, b2, n1, n2 = p

    # Create f = (x1',y1',x2',y2'):
    f = [y1,(-b1 * y1 - k1 * x1 + n1 * (x1 ** 3) - k2 * (x1-x2) + n2 * (x1 - x2) ** 3) / m1, y2, (-b2 * y2 - k2 * (x2 - x1) + n2 * (x2 - x1) ** 3) / m2]
    return f

# %%
# Use ODEINT to solve the differential equations defined by the vector field
from scipy.integrate import odeint

# Parameter values
# Masses:
m1 = 1.0
m2 = 1.0

# Spring constants
k1 = 0.4
k2 = 1.808

# Friction coefficients
b1 = 0.0
b2 = 0.0


#Coeficientes no lineales
n1=-1/6
n2=-1/10

# Initial conditions
# x1 and x2 are the initial displacements; y1 and y2 are the initial velocities
x1 = 1.0
y1 = 0.0
x2 = -1/2
y2 = 0.0

# ODE solver parameters
abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 50.0
numpoints = 250

# Create the time samples for the output of the ODE solver.
# I use a large number of points, only because I want to make
# a plot of the solution that looks nice.
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Pack up the parameters and initial conditions:
p = [m1, m2, k1, k2, b1, b2, n1, n2]
w0 = [x1, y1, x2, y2]

# Call the ODE solver.
wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('nonlinear3.1.dat', 'w') as f:
    # Print & save the solution.
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], w1[2], w1[3], file=f)

# %%
import numpy
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
import matplotlib.pyplot as plt
# %matplotlib inline

t, x1, y1, x2, y2 = loadtxt('nonlinear3.1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x')
ylabel('y')
grid(True)
lw = 1.5

plot(x1, y1, 'black', linewidth=lw)
plt.xlim=[-2,2]
plt.ylim=[-2,2]

title('Phase plot for x1')
savefig('nonlinear3.1.1.png', dpi=100)

# %%
t, x1, y1, x2, y2 = loadtxt('nonlinear3.1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x')
ylabel('y')
grid(True)
lw = 1.5

plot(x2, y2, 'black', linewidth=lw)
plt.xlim=[-2,2]
plt.ylim=[-2,2]

title('Phase plot for x1')
savefig('nonlinear3.1.2.png', dpi=100)

# %%
t, x1, y1, x2, y2 = loadtxt('nonlinear3.1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x')
grid(True)
lw = 1.5

plot(t, x1, 'black', linewidth=lw)

title('Phase plot for x1')
savefig('nonlinear3.1.3.png', dpi=100)

# %%
t, x1, y1, x2, y2 = loadtxt('nonlinear3.1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x')
grid(True)
lw = 1.5

plot(t, x2, 'black', linewidth=lw)

title('Phase plot for x1')
savefig('nonlinear3.1.4.png', dpi=100)

# %%
t, x1, y1, x2, y2 = loadtxt('nonlinear3.1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x')
grid(True)
lw = 1.5

plot(t, x1, 'black', linewidth=lw)
plot(t, x2, 'black', linewidth=lw)

title('Phase plot for x1 and x2')
savefig('nonlinear3.1.5.png', dpi=100)

# %%
t, x1, y1, x2, y2 = loadtxt('nonlinear3.1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x1')
ylabel('x2')
grid(True)
lw = 1.5

plot(x1, x2, 'black', linewidth=lw)

title('Phase plot for x1')
savefig('nonlinear3.1.6.png', dpi=100)

# %%
def vectorfield(w, t, p):

    x1, y1, x2, y2 = w
    m1, m2, k1, k2, L1, L2, b1, b2, n1, n2 = p

    f = [y1,
         (-b1 * y1 - k1 * (x1 - L1) + n1 * (x1 - L1)**3 + k2 * (x2 - x1 - L2) + n2 * (x1 - x2)**3) / m1,
         y2,
         (-b2 * y2 - k2 * (x2 - x1 - L2) + n2 * (x2 - x1)**3) / m2]
    return f

# %%
#Use ODEINT function
from scipy.integrate import odeint

m1 = 1.0
m2 = 1.0

k1 = 0.4
k2 = 1.808

L1 = 0.0
L2 = 0.0

b1 = 0.0
b2 = 0.0

n1 = -(1.0/6.0)
n2 = -(1.0/10.0)

x1 = -0.5
y1 = 0.5
x2 = 3.001
y2 = 5.9

abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 200.0
numpoints = 2150


t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

p = [m1, m2, k1, k2, L1, L2, b1, b2, n1, n2]
w0 = [x1, y1, x2, y2]

wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('nonlinear3.2.dat', 'w') as f:
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], w1[2], w1[3],file=f)

# %%
import numpy 
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
import matplotlib.pyplot as plt
# %matplotlib inline

t, x1, y1, x2, y2 = loadtxt('nonlinear3.2.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x')
ylabel('v')
grid(True)
lw = 1.5

plot(x1, y1, 'black', linewidth=lw)

plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)

title('Phase plot for x1')
savefig('nonlinear3.2.1.png', dpi=100)

# %%
figure(1, figsize=(6, 4.5))

xlabel('x')
ylabel('v')
grid(True)
lw = 1.5

plot(x2, y2, "black", linewidth=lw)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)

title('Phase plot for x2')
savefig('nonlinear3.2.2.png', dpi=100)

# %%
figure(1, figsize=(6, 4.5))

grid(True)
lw = 1.5

plot(x1, x2, 'black', linewidth=lw)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)

title('x1 vs x2')
savefig('nonlinear3.2.3.png', dpi=100)

# %%
def vectorfield(w, t, p):

    x1, y1, x2, y2 = w
    m1, m2, k1, k2, L1, L2, b1, b2, n1, n2 = p

    #Creamos f = (x1',y1',x2',y2')
    f = [y1,
         (-b1 * y1 - k1 * (x1 - L1) + n1 * (x1 - L1)**3 + k2 * (x2 - x1 - L2) + n2 * (x1 - x2)**3) / m1,
         y2,
         (-b2 * y2 - k2 * (x2 - x1 - L2) + n2 * (x2 - x1)**3) / m2]
    return f

# %%
from scipy.integrate import odeint


m1 = 1.0
m2 = 1.0

k1 = 0.4
k2 = 1.808

L1 = 0.0
L2 = 0.0

b1 = 0.0
b2 = 0.0

n1 = -(1.0/6.0)
n2 = -(1.0/10.0)

x1 = -0.6
y1 = 0.5
x2 = 3.001
y2 = 5.9

abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 200.0
numpoints = 2150

t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

p = [m1, m2, k1, k2, L1, L2, b1, b2, n1, n2]
w0 = [x1, y1, x2, y2]

wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('nonlinear3.3.dat', 'w') as f:
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], w1[2], w1[3],file=f)

# %%
import numpy 
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
import matplotlib.pyplot as plt
# %matplotlib inline

t, x1, y1, x2, y2 = loadtxt('nonlinear3.3.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x')
ylabel('v')
grid(True)
lw = 1.5

plot(x1, y1, 'black', linewidth=lw)

plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)


title('Phase plot for x1')
savefig('nonlinear3.3.1.png', dpi=100)

# %%
figure(1, figsize=(6, 4.5))

xlabel('x')
ylabel('v')
grid(True)
lw = 1.5

plot(x2, y2, "black", linewidth=lw)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)

title('Phase plot for x2')
savefig('nonlinear3.3.2.png', dpi=100)

# %%
figure(1, figsize=(6, 4.5))

grid(True)
lw = 1.5

plot(x1, x2, 'black', linewidth=lw)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)

title('x1 vs x2')
savefig('nonlinear3.3.3.png', dpi=100)

# %%
import numpy as np
def vectorfield(w, t, p):

    x1, y1, x2, y2 = w
    m1, m2, k1, k2, L1, L2, b1, b2, n1, n2, F1, F2, w1, w2 = p

    #Creamos f = (x1',y1',x2',y2')
    f = [y1,
         (-b1 * y1 - k1 * (x1 - L1) + n1 * (x1 - L1)**3 + k2 * (x2 - x1 - L2) + n2 * (x1 - x2)**3 + F1 * np.cos(w1*t)) / m1,
         y2,
         (-b2 * y2 - k2 * (x2 - x1 - L2) + n2 * (x2 - x1)**3 + F2 * np.cos(w2*t)) / m2]
    return f

# %%
from scipy.integrate import odeint

m1 = 1.0
m2 = 1.0

k1 = (2.0/5.0)
k2 = 1

L1 = 0.0
L2 = 0.0

b1 = (1.0/10.0)
b2 = (1.0/5.0)

n1 = (1.0/6.0)
n2 = (1.0/10.0)

F1 = (1.0/3.0)
F2 = (1.0/5.0)

w1 = 1
w2 = (3.0/5.0)

# Condiciones iniciales
x1 = 0.7
y1 = 0
x2 = 0.1
y2 = 0

abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 250.0
numpoints = 2150

t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

p = [m1, m2, k1, k2, L1, L2, b1, b2, n1, n2, F1, F2, w1, w2]
w0 = [x1, y1, x2, y2]

wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('addedforce4.1.dat', 'w') as f:
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], w1[2], w1[3],file=f)

# %%
import numpy 
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
import matplotlib.pyplot as plt
# %matplotlib inline

t, x1, y1, x2, y2 = loadtxt('addedforce4.1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x')
ylabel('v')
grid(True)
lw = 1.5

plot(x1, y1, 'black', linewidth=lw)

plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)

title('Phase plot for x1')
savefig('addedforce4.1.1.png', dpi=100)

# %%
figure(1, figsize=(6, 4.5))

xlabel('x')
ylabel('v')
grid(True)
lw = 1.5

plot(x2, y2, "black", linewidth=lw)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)


title('Phase plot for x2')
savefig('addedforce4.1.2.png', dpi=100)

# %%
figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x')
grid(True)
lw = 1.5

plot(t, x1, 'black', linewidth=lw)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)

title('x1')
savefig('addedforce4.1.3.png', dpi=100)

# %%
figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x')
grid(True)
lw = 1.5

plot(t, x2, 'black', linewidth=lw)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)

title('x2')
savefig('addedforce4.1.4.png', dpi=100)

# %%
t, x1, y1, x2, y2 = loadtxt('addedforce4.1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x')
grid(True)
lw = 1.5

plot(t, x1, 'black', linewidth=lw)

plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)

y = [-2, -1.5, -1,-0.5,0,0.5,1,1.5,2]
plt.yticks(y)

title('Mass position for x1')
savefig('addedforce4.1.5.png', dpi=100)

# %%
t, x1, y1, x2, y2 = loadtxt('addedforce4.1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x')
grid(True)
lw = 1.5

plot(t, x2, 'black', linewidth=lw)

plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)

y = [-2, -1.5, -1,-0.5,0,0.5,1,1.5,2]
plt.yticks(y)

title('Mass position for x2')
savefig('addedforce4.1.5.png', dpi=100)

# %%
t, x1, y1, x2, y2 = loadtxt('addedforce4.1.dat', unpack=True, skiprows=1828)

figure(1, figsize=(6, 4.5))

grid(True)
lw = 1.5

plot(x1, x2, 'black', linewidth=lw)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)

title('x1 vs x2')
savefig('addedforce4.1.6.png', dpi=100)
