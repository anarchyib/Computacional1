# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("df2017_capepw00Z.csv", header=None, names=['Date', 'CAPE', 'PW'])

# %%
df.CAPE=pd.to_numeric(df.CAPE, errors='coerce')
df.head()
# Out:
#          Date  CAPE    PW
# 0  01 01 2017   0.0  1.98
# 1  02 01 2017   0.0  3.12
# 2  03 01 2017   0.0  3.00
# 3  04 01 2017   0.0  2.29
# 4  05 01 2017   0.0  2.80

# %%
df['Ndate'] = pd.to_datetime(df['Date'], format='%d %m %Y')
df['month'] = df['Ndate'].dt.month
df.head()
# Out:
#          Date  CAPE    PW      Ndate  month
# 0  01 01 2017   0.0  1.98 2017-01-01      1
# 1  02 01 2017   0.0  3.12 2017-01-02      1
# 2  03 01 2017   0.0  3.00 2017-01-03      1
# 3  04 01 2017   0.0  2.29 2017-01-04      1
# 4  05 01 2017   0.0  2.80 2017-01-05      1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="CAPE", data=df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="PW", data=df)
plt.show()

# %%
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

g = sns.jointplot("CAPE", "PW", data=df, kind="reg",
                   color="r", size=7)
plt.show(g)

# %%
g = sns.lmplot(x="CAPE", y="PW", hue="month",
               truncate=True, size=5, data=df)
plt.show(g)
